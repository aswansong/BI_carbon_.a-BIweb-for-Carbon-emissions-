# %%
import pandas as pd

data = pd.read_excel("2019年30个省份排放清单.xlsx")
data
# Out:
#                                            Unnamed: 0     Raw Coal  \
# 0                                                 NaN       Mt CO2
# 1                                                 NaN          NaN
# 2                                   Total Consumption      55.4847
# 3   Farming, Forestry, Animal Husbandry, Fishery a...   0.00493201
# 4   Coal Mining and Dressing                      ...            0
# 5   Petroleum and Natural Gas Extraction          ...            0
# 6   Ferrous Metals Mining and Dressing            ...            0
# 7   Nonferrous Metals Mining and Dressing         ...            0
# 8   Nonmetal Minerals Mining and Dressing         ...            0
# 9   Other Minerals Mining and Dressing            ...            0
# 10  Logging and Transport of Wood and Bamboo      ...            0
# 11  Food Processing                               ...     0.109974
# 12  Food Production                               ...    0.0563114
# ...
